# %%
import pandas as pd
import googlemaps
import string

# %%
gmaps = googlemaps.Client(key='AIzaSyCHKEv_ZsvjFamVFYAXlL8joL6h04dSDtg')
property_df = pd.read_csv('property.csv', encoding = "ISO-8859-1")

# %%
def get_coordinates(address):
    printable_set = set(string.printable)
    addr_set = set("".join(set(address)))
    if addr_set.issubset(printable_set):
        response = gmaps.geocode(address)
        if not response:
            return None
        else:
            return response[0]['geometry']['location']
    else:
        return None

# %%
property_df['Coordinates'] = property_df['CityAddress'].apply(get_coordinates)
property_df
# Out:
#               City  Year                                        CityAddress  \
# 0           ampang  2017                            ampang, jalan cahaya 15
# 1           ampang  2015                            ampang, jalan cahaya 15
# 2           ampang  2016                            ampang, jalan dagang 8a
# 3           ampang  2015                            ampang, jalan dagang 10
# 4      subang jaya  2017                        subang jaya, jalan usj 1/33
# 5      subang jaya  2017                        subang jaya, jalan usj 1/31
# 6      subang jaya  2015                        subang jaya, jalan usj 1/33
# 7      subang jaya  2014                        subang jaya, jalan usj 1/33
# 8      subang jaya  2013                        subang jaya, jalan usj 1/33
# 9      subang jaya  2016                              subang jaya, ss 13/3f
# 10     subang jaya  2015                         subang jaya, jalan ss13/3e
# 11     subang jaya  2015                        subang jaya, jalan ss 13/3b
# 12     subang jaya  2015                        subang jaya, jalan ss 13/6c
# 13     subang jaya  2014                        subang jaya, jalan ss 13/6b
# 14        serendah  2017                        serendah, jalan sungai choh
# 15        semenyih  2016  semenyih, jalan 1, kawasan perindustrian hi-te...
# 16        semenyih  2016  semenyih, jalan 1, kawasan perindustrian hi-te...
# 17        semenyih  2015                          semenyih, jalan hi-tech 5
# 18        semenyih  2014                                  semenyih, jalan 1
# 19        semenyih  2013                          semenyih, jalan hi-tech 6
# 20        semenyih  2013  semenyih, jalan 1, kawasan perindustrian hi-te...
# 21        semenyih  2013  semenyih, jalan 1, kawasan perindustrian hi-te...
# 22          kajang  2016              kajang, jalan perindustrian bj 2t 1/1
# 23          kajang  2015                    kajang, off jalan simpang balak
# 24           klang  2017                         klang, jalan perusahaan 27
# 25           klang  2014                         klang, jalan saksama 25/39
# 26           klang  2013                          klang, jalan unggul 25/40
# 27        selayang  2016                              selayang, jalan su 23
# 28   petaling jaya  2015                               petaling jaya, ss8/4
# 29   petaling jaya  2013                               petaling jaya, ss8/6
# ..             ...   ...                                                ...
# 919      shah alam  2014                         shah alam, jalan astana 1a
# 920      shah alam  2014  shah alam, jalan keluli 7/109 seksyen 7 shah alam
# 921      shah alam  2013  shah alam, jalan keluli 7/109 seksyen 7 shah alam
# 922      shah alam  2016                             shah alam, ragum 15/17
# 923      shah alam  2016             shah alam, jalan anggerek mokara 31/59
# 924      shah alam  2016             shah alam, jalan anggerik mokara 31/51
# 925      shah alam  2016             shah alam, jalan anggerik makora 31/60
# 926      shah alam  2015             shah alam, jalan anggerik mokara 31/60
# 927      shah alam  2015             shah alam, jalan anggerik mokara 31/58
# 928      shah alam  2015             shah alam, jalan anggerik mokara 31/62
# 929      shah alam  2014             shah alam, jalan anggerik mokara 13/62
# 930      shah alam  2014             shah alam, jalan anggerik mokara 31/62
# 931      shah alam  2017                    shah alam, jalan sepadu 25/123a
# 932      shah alam  2017                    shah alam, jalan sepadu 25/123a
# 933      shah alam  2016                     shah alam, jalan sepadu 25/123
# 934      shah alam  2016                    shah alam, jalan sepadu 25/123a
# 939                  SEMI-D FACTORY   10,637      451
# 940                  SEMI-D FACTORY   10,637      451
# 941                  SEMI-D FACTORY   10,637      423
# 942                  SEMI-D FACTORY   11,997      400
# 943                  SEMI-D FACTORY   10,677      468
# 944                  SEMI-D FACTORY   10,637      451
# 945                  SEMI-D FACTORY   10,637      333
# 946                  SEMI-D FACTORY   11,329      415
# 947                  SEMI-D FACTORY   13,448      602
# 948                  SEMI-D FACTORY    8,858      570
#
#                                         Coordinates
# 0            {'lat': 3.1449836, 'lng': 101.7594994}
# 1            {'lat': 3.1449836, 'lng': 101.7594994}
# 2            {'lat': 3.1344646, 'lng': 101.7775601}
# 3            {'lat': 3.1345373, 'lng': 101.7763681}
# 4            {'lat': 3.0489518, 'lng': 101.5997035}
# 5            {'lat': 3.0479988, 'lng': 101.5989691}
# 6            {'lat': 3.0489518, 'lng': 101.5997035}
# 7            {'lat': 3.0489518, 'lng': 101.5997035}
# 8            {'lat': 3.0489518, 'lng': 101.5997035}
# 9            {'lat': 3.0695499, 'lng': 101.5953263}
# 10            {'lat': 3.068417, 'lng': 101.5982366}
# 11           {'lat': 3.0703478, 'lng': 101.5979657}
# 12           {'lat': 3.0676356, 'lng': 101.5995145}
# 13            {'lat': 3.066329, 'lng': 101.5983729}
# 14           {'lat': 3.3522114, 'lng': 101.5815692}
# 15           {'lat': 2.9759054, 'lng': 101.8660717}
# 16           {'lat': 2.9759054, 'lng': 101.8660717}
# 17           {'lat': 2.9905507, 'lng': 101.8671799}
# 18           {'lat': 2.9753623, 'lng': 101.8667409}
# 19           {'lat': 2.9909355, 'lng': 101.8659943}
# 20           {'lat': 2.9759054, 'lng': 101.8660717}
# 21           {'lat': 2.9759054, 'lng': 101.8660717}
# 22           {'lat': 3.0133685, 'lng': 101.7433215}
# 23           {'lat': 3.0164511, 'lng': 101.7769009}
# 24           {'lat': 2.9964702, 'lng': 101.4234531}
# 25           {'lat': 3.0365015, 'lng': 101.5344834}
# 26           {'lat': 3.0351079, 'lng': 101.5351891}
# 27   {'lat': 3.237950300000001, 'lng': 101.6406231}
# 28           {'lat': 3.0883247, 'lng': 101.6103232}
# 29           {'lat': 3.0904889, 'lng': 101.6078927}
# ..                                              ...
# 919          {'lat': 3.0864459, 'lng': 101.4524348}
# 920          {'lat': 3.0640131, 'lng': 101.4744133}
# 921          {'lat': 3.0640131, 'lng': 101.4744133}
# 922          {'lat': 3.0689697, 'lng': 101.5436839}
# 923          {'lat': 2.9769147, 'lng': 101.5426892}
# 924          {'lat': 2.9810956, 'lng': 101.5481109}
# 925             {'lat': 2.977829, 'lng': 101.54085}
# 926             {'lat': 2.977829, 'lng': 101.54085}
# 927           {'lat': 2.976555, 'lng': 101.5477965}
# 928           {'lat': 2.9758865, 'lng': 101.541828}
# 929          {'lat': 2.9783301, 'lng': 101.5398683}
# 930           {'lat': 2.9758865, 'lng': 101.541828}
# 931          {'lat': 3.0291456, 'lng': 101.5474687}
# 932          {'lat': 3.0291456, 'lng': 101.5474687}
# 933          {'lat': 3.0268209, 'lng': 101.5441985}
# 934          {'lat': 3.0291456, 'lng': 101.5474687}
# 935          {'lat': 3.0291456, 'lng': 101.5474687}
# 936          {'lat': 3.0105094, 'lng': 101.5269081}
# 937          {'lat': 3.0291456, 'lng': 101.5474687}
# 938          {'lat': 3.0291456, 'lng': 101.5474687}
# 939          {'lat': 3.0435918, 'lng': 101.5019201}
# 940          {'lat': 3.0435918, 'lng': 101.5019201}
# 941          {'lat': 3.0435918, 'lng': 101.5019201}
# 942          {'lat': 3.0638494, 'lng': 101.5442766}
# 943          {'lat': 3.0638494, 'lng': 101.5442766}
# 944          {'lat': 3.0435918, 'lng': 101.5019201}
# 945          {'lat': 3.0638494, 'lng': 101.5442766}
# 946          {'lat': 3.0638494, 'lng': 101.5442766}
# 947          {'lat': 3.0638494, 'lng': 101.5442766}
# 948          {'lat': 3.0638494, 'lng': 101.5442766}
#
# [949 rows x 7 columns]

# %%
gmaps = googlemaps.Client(key='AIzaSyCHKEv_ZsvjFamVFYAXlL8joL6h04dSDtg')
addr_df = pd.read_excel('Workbook1.xlsx', sheet_name = "remove NA", encoding = "ISO-8859-1")
df = addr_df[1:40]
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-6a7b3ff19fcf> in <module>()
#       1 gmaps = googlemaps.Client(key='AIzaSyCHKEv_ZsvjFamVFYAXlL8joL6h04dSDtg')
# ----> 2 addr_df = pd.read_excel('Workbook1.xlsx', sheet_name = "remove NA", encoding = "ISO-8859-1")
#       3 df = addr_df[1:40]
#       4 df
#
# /Users/shenghao/anaconda/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /Users/shenghao/anaconda/lib/python3.6/site-packages/pandas/io/excel.py in read_excel(io, sheet_name, header, skiprows, skip_footer, index_col, names, usecols, parse_dates, date_parser, na_values, thousands, convert_float, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     228
#     229     if not isinstance(io, ExcelFile):
# --> 230         io = ExcelFile(io, engine=engine)
#     231
#     232     return io._parse_excel(
#
# /Users/shenghao/anaconda/lib/python3.6/site-packages/pandas/io/excel.py in __init__(self, io, **kwds)
#     292             self.book = xlrd.open_workbook(file_contents=data)
#     293         elif isinstance(self._io, compat.string_types):
# --> 294             self.book = xlrd.open_workbook(self._io)
#     295         else:
#     296             raise ValueError('Must explicitly set engine if not passing in'
#
# /Users/shenghao/anaconda/lib/python3.6/site-packages/xlrd/__init__.py in open_workbook(filename, logfile, verbosity, use_mmap, file_contents, encoding_override, formatting_info, on_demand, ragged_rows)
#     393         peek = file_contents[:peeksz]
#     394     else:
# --> 395         with open(filename, "rb") as f:
#     396             peek = f.read(peeksz)
#     397     if peek == b"PK\x03\x04": # a ZIP file
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Workbook1.xlsx'

# %%
my_distance = gmaps.distance_matrix('Chicago', 'New York City')

# %%
my_distance['rows'][0]['elements'][0]['distance']['text']
# Out:
# '1,282 km'

# %%
my_distance['rows'][0]['elements'][0]['duration']['text']
# Out:
# '12 hours 10 mins'

# %%
my_distance['rows'][0]
# Out:
# {'elements': [{'distance': {'text': '1,282 km', 'value': 1281617},
#    'duration': {'text': '12 hours 10 mins', 'value': 43797},
#    'status': 'OK'}]}

# %%
def getDistDur(origin):
    dest = 'Kuala Lumpur'
    result = gmaps.distance_matrix(origin, dest)
    return result['rows'][0]['elements'][0]['distance']['text']

# %%
df['Address'].apply(getDistDur)
# Out:
# 1    15.4 km
# 2    16.6 km
# 3    16.5 km
# 4    24.5 km
# Name: Address, dtype: object

# %%
geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')
geocode_result
#geocode_result[0]['geometry']['location']
# Out:
# [{'address_components': [{'long_name': 'Google Building 41',
#     'short_name': 'Google Building 41',
#     'types': ['premise']},
#    {'long_name': '1600', 'short_name': '1600', 'types': ['street_number']},
#    {'long_name': 'Amphitheatre Parkway',
#     'short_name': 'Amphitheatre Pkwy',
#     'types': ['route']},
#    {'long_name': 'Mountain View',
#     'short_name': 'Mountain View',
#     'types': ['locality', 'political']},
#    {'long_name': 'Santa Clara County',
#     'short_name': 'Santa Clara County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'California',
#     'short_name': 'CA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '94043', 'short_name': '94043', 'types': ['postal_code']}],
#   'formatted_address': 'Google Building 41, 1600 Amphitheatre Pkwy, Mountain View, CA 94043, USA',
#   'geometry': {'bounds': {'northeast': {'lat': 37.4228775, 'lng': -122.085133},
#     'southwest': {'lat': 37.4221145, 'lng': -122.0860002}},
#    'location': {'lat': 37.4224082, 'lng': -122.0856086},
#    'location_type': 'ROOFTOP',
#    'viewport': {'northeast': {'lat': 37.4238449802915,
#      'lng': -122.0842176197085},
#     'southwest': {'lat': 37.4211470197085, 'lng': -122.0869155802915}}},
#   'place_id': 'ChIJxQvW8wK6j4AR3ukttGy3w2s',
#   'types': ['premise']}]
